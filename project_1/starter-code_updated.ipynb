# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# Define the problem you are finding answers for from the data given.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Read in the files:
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#See first 10 rows of dataframe:
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
#See first 10 rows of dataframe:
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
# In sat_2017, it shows the different number of states, the state names, the participation rate of students for the test, the mean score for evidence-based reading and writing, the mean score for math and the total scores of this 2 subjects combined.
#
# In act_2017, it shows the different number of states, the state names, the participation rate of students for the test, the mean score for English, the mean score for Math, the mean score for Reading, the mean score for Science and the mean score of this 4 subjects combined.

# %% [markdown]
# #### 4a. Does the data look complete?

# %%
#See info of dataframe:
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
#See info of dataframe:
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# Answer: The data for sat_2017 and act_2017 looks complete as there are no missing cells or null values in the data series.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
#check data of dataframe visually:
sat_2017
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
#check data of dataframe visually:
act_2017
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# Answer:
# SAT - Lowest score is 200, Highest score is 800 per sub-test
# ACT - Lowest score is 1, Highest score is 36 per sub-test
#
# SAT scores: Maryland's Math score of 52 is incorrect. It should be 524.
# ACT socres: Maryland's Science score of 2.3 is incorrect. It should be 23.2

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#Rectify data error and reassigning value back to data series
sat_2017.loc[sat_2017['State']=='Maryland', 'Math'] = 524
sat_2017.loc[sat_2017['State']=='Maryland', 'Math']
# Out:
# 20    524
# Name: Math, dtype: int64

# %%
#Rectify data error and reassigning value back to data series
act_2017.loc[act_2017['State']=='Maryland', 'Science'] = 23.2
act_2017.loc[act_2017['State']=='Maryland', 'Science']
# Out:
# 21    23.2
# Name: Science, dtype: float64

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#check data types
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
#check data types
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
#check data types
act_2017.tail()
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: <br>
# For sat_2017, the participation rates should be a float.<br>
# For act_2017, the participation rates and composite should be a float instead of an object.<br>
# Fot act_2017, there is an x appended to the composite data of the State, Wyoming.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#function to convert string to float

def convert_string_to_float(ds):
    
    return float(ds.replace('%', ''))

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#Rectify data error and reassigning value back to data series
act_2017.loc[act_2017['State']=='Wyoming', 'Composite'] = 20.2

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#Convert and reassign back to data series
sat_2017['Participation'] = sat_2017['Participation'].map(convert_string_to_float)

# %%
#Convert and reassign back to data series
act_2017['Participation'] = act_2017['Participation'].map(convert_string_to_float)

# %%
#Convert and reassign back to data series
act_2017['Composite'] = act_2017['Composite'].astype(float)

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#check data types
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
#check data types
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#check column names
sat_2017.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5.0                                 593   572   1165
# 1      Alaska           38.0                                 547   533   1080
# 2     Arizona           30.0                                 563   553   1116
# 3    Arkansas            3.0                                 614   594   1208
# 4  California           53.0                                 531   524   1055

# %%
#Rename the column names and make them permanent
sat_2017.rename(columns={
    "State" : "state",
    "Participation": "sat17_p_rate",
    "Evidence-Based Reading and Writing": "sat17_ebase_read_write",
    "Math": "sat17_math",
    "Total": "sat17_total"
},inplace=True)

# %%
#check column names
sat_2017.head()
# Out:
#         state  sat17_p_rate  sat17_ebase_read_write  sat17_math  sat17_total
# 0     Alabama           5.0                     593         572         1165
# 1      Alaska          38.0                     547         533         1080
# 2     Arizona          30.0                     563         553         1116
# 3    Arkansas           3.0                     614         594         1208
# 4  California          53.0                     531         524         1055

# %%
#check column names
act_2017.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           60.0     20.3  20.7     21.4     21.0       21.0
# 1   Alabama          100.0     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           65.0     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           62.0     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas          100.0     18.9  19.0     19.7     19.5       19.4

# %%
#Rename the column names and make them permanent
act_2017.rename(columns={
    "State" : "state",
    "Participation": "act17_p_rate",
    "English": "act17_english",
    "Math": "act17_math",
    "Reading": "act17_reading",
    "Science": "act17_science",
    "Composite": "act17_composite"
},inplace=True)

# %%
#check column names
act_2017.head()
# Out:
#       state  act17_p_rate  act17_english  act17_math  act17_reading  \
# 0  National          60.0           20.3        20.7           21.4
# 1   Alabama         100.0           18.9        18.4           19.7
# 2    Alaska          65.0           18.7        19.8           20.4
# 3   Arizona          62.0           18.6        19.8           20.1
# 4  Arkansas         100.0           18.9        19.0           19.7
#
#    act17_science  act17_composite
# 0           21.0             21.0
# 1           19.4             19.2
# 2           19.9             19.8
# 3           19.8             19.7
# 4           19.5             19.4

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |act_2017|dataframe|ACT|This stores the ACT data for 2017|
# |sat_2017|dataframe|SAT|This stores the SAT data for 2017|
# |convert_string_to_float(ds)|function|N/A|function to convert string to float|
# |act_sat_2017|dataframe|ACT/SAT|This stores the ACT/SAT data for 2017|
# |sat_2018|dataframe|SAT|This stores the SAT data for 2018|
# |act_2018|dataframe|ACT|This store the ACT data for 2018|
# |combined_df|dataframe|ACT/SAT|This stores the ACT/SAT data for 2017 & 2018|
# |std_dev(data)|function|N/A|function to calculate the standard deviation|
# |sd|dataframe|standard deviation|This stores the calculated standard deviation values|
# |np_sd|dataframe|standard deviation|This stores the numpy calculated standard deviation values|
# |state_p_rate|group.dataframe|participation rates|This stores the participation rates data series for ACT/SAT/2017/2018|
# |state_composite|group.dataframe|participation rates|This stores the composite/total score data series for ACT/SAT/2017/2018|
# |subplot_histograms|function|N/A|function to plot out subplots of histograms|
# |columns|string|dataseries names|Assigning values for arguents to be used in histogram function|
# |titles|string|dataseries names|Assigning values for arguents to be used in histogram function|
# |xlabels|string|dataseries names|Assigning values for arguents to be used in histogram function|
# |sampler(population, n, k)|function|N/A|function to generate sample means from a sample population|
# |dist_plotter(sample)|function|N/A|function to plot a histogram|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#check data
sat_2017.head()
# Out:
#         state  sat17_p_rate  sat17_ebase_read_write  sat17_math  sat17_total
# 0     Alabama           5.0                     593         572         1165
# 1      Alaska          38.0                     547         533         1080
# 2     Arizona          30.0                     563         553         1116
# 3    Arkansas           3.0                     614         594         1208
# 4  California          53.0                     531         524         1055

# %%
#Comparing the 2 datasets, the extra row is 'National' in act_2017
act_2017.head()
# Out:
#       state  act17_p_rate  act17_english  act17_math  act17_reading  \
# 0  National          60.0           20.3        20.7           21.4
# 1   Alabama         100.0           18.9        18.4           19.7
# 2    Alaska          65.0           18.7        19.8           20.4
# 3   Arizona          62.0           18.6        19.8           20.1
# 4  Arkansas         100.0           18.9        19.0           19.7
#
#    act17_science  act17_composite
# 0           21.0             21.0
# 1           19.4             19.2
# 2           19.9             19.8
# 3           19.8             19.7
# 4           19.5             19.4

# %%
#Remove 'National' row
act_2017.drop(index=0,axis=0,inplace=True)

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Merge dataframe act_2017 and sat_2017:
act_sat_2017 = pd.merge(act_2017, sat_2017, on='state', how='left')

# %%
#check dataframe
act_sat_2017.head()
# Out:
#         state  act17_p_rate  act17_english  act17_math  act17_reading  \
# 0     Alabama         100.0           18.9        18.4           19.7
# 1      Alaska          65.0           18.7        19.8           20.4
# 2     Arizona          62.0           18.6        19.8           20.1
# 3    Arkansas         100.0           18.9        19.0           19.7
# 4  California          31.0           22.5        22.7           23.1
#
#    act17_science  act17_composite  sat17_p_rate  sat17_ebase_read_write  \
# 0           19.4             19.2           5.0                     593
# 1           19.9             19.8          38.0                     547
# 2           19.8             19.7          30.0                     563
# 3           19.5             19.4           3.0                     614
# 4           22.2             22.8          53.0                     531
#
#    sat17_math  sat17_total
# 0         572         1165
# 1         533         1080
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#Write dataframe to .csv file
act_sat_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#Read dataframe from .csv file
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018_updated.csv')

# %%
#Check data visually
sat_2018
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
#check data types
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
#Convert string to float and reassign back to data series
sat_2018['Participation'] = sat_2018['Participation'].map(convert_string_to_float)

# %%
#check data types
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
#Rename the column names and set them to permanent
sat_2018.rename(columns={
    "State" : "state",
    "Participation": "sat18_p_rate",
    "Evidence-Based Reading and Writing": "sat18_ebase_read_write",
    "Math": "sat18_math",
    "Total": "sat18_total"
},inplace=True)

# %%
#Check the column names
sat_2018.head()
# Out:
#         state  sat18_p_rate  sat18_ebase_read_write  sat18_math  sat18_total
# 0     Alabama           6.0                     595         571         1166
# 1      Alaska          43.0                     562         544         1106
# 2     Arizona          29.0                     577         572         1149
# 3    Arkansas           5.0                     592         576         1169
# 4  California          60.0                     540         536         1076

# %%
#Check data visually
act_2018
# Out:
#                    State  Percentage of Students Tested  \
# 0                Alabama                            100
# 1                 Alaska                             33
# 2                Arizona                             66
# 3               Arkansas                            100
# 4             California                             27
# 5               Colorado                             30
# 6            Connecticut                             26
# 7               Delaware                             17
# 8   District of Columbia                             32
# 9                Florida                             66
# 10               Georgia                             53
# 11                Hawaii                             89
# 12                 Idaho                             36
# 13              Illinois                             43
# 14               Indiana                             32
# 15                  Iowa                             68
# ...

# %%
#Check the data types
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          51 non-null     object
#  1   Percentage of Students Tested  51 non-null     int64
#  2   Average Composite Score        51 non-null     float64
#  3   Average English Score          51 non-null     float64
#  4   Average Math Score             51 non-null     float64
#  5   Average Reading Score          51 non-null     float64
#  6   Average Science Score          51 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
#Convert object to float and reassign back to data series
act_2018['Percentage of Students Tested'] = act_2018['Percentage of Students Tested'].astype(float)

# %%
#check the data types
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          51 non-null     object
#  1   Percentage of Students Tested  51 non-null     float64
#  2   Average Composite Score        51 non-null     float64
#  3   Average English Score          51 non-null     float64
#  4   Average Math Score             51 non-null     float64
#  5   Average Reading Score          51 non-null     float64
#  6   Average Science Score          51 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %%
#rename the column names and set them permanent
act_2018.rename(columns={
    "State" : "state",
    "Percentage of Students Tested": "act18_p_rate",
    "Average Composite Score": "act18_composite",
    "Average English Score": "act18_english",
    "Average Math Score": "act18_math",
    "Average Reading Score": "act18_reading",
    "Average Science Score": "act18_science"
},inplace=True)

# %%
#check the column names
act_2018.head()
# Out:
#         state  act18_p_rate  act18_composite  act18_english  act18_math  \
# 0     Alabama         100.0             19.1           18.9        18.3
# 1      Alaska          33.0             20.8           19.8        20.6
# 2     Arizona          66.0             19.2           18.2        19.4
# 3    Arkansas         100.0             19.4           19.1        18.9
# 4  California          27.0             22.7           22.5        22.5
#
#    act18_reading  act18_science
# 0           19.6           19.0
# 1           21.6           20.7
# 2           19.5           19.2
# 3           19.7           19.4
# 4           23.0           22.1

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
#merge act_2018 data frame to act_sat_2017 dataframe as combined_df
combined_df = pd.merge(act_sat_2017, act_2018, on='state', how='left')

# %%
#merge sat_2018 data frame to combined_df dataframe
combined_df = pd.merge(combined_df, sat_2018, on='state', how='left')

# %%
#check the data
combined_df.head()
# Out:
#         state  act17_p_rate  act17_english  act17_math  act17_reading  \
# 0     Alabama         100.0           18.9        18.4           19.7
# 1      Alaska          65.0           18.7        19.8           20.4
# 2     Arizona          62.0           18.6        19.8           20.1
# 3    Arkansas         100.0           18.9        19.0           19.7
# 4  California          31.0           22.5        22.7           23.1
#
#    act17_science  act17_composite  sat17_p_rate  sat17_ebase_read_write  \
# 0           19.4             19.2           5.0                     593
# 1           19.9             19.8          38.0                     547
# 2           19.8             19.7          30.0                     563
# 3           19.5             19.4           3.0                     614
# 4           22.2             22.8          53.0                     531
#
#    sat17_math  ...  act18_p_rate  act18_composite  act18_english  act18_math  \
# ...

# %%
#Write dataframe to .csv file
combined_df.to_csv('../data/final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Transpose describe method outputs, switch the x-axis with y-axis
combined_df.describe().transpose()
# Out:
#                         count         mean        std    min      25%     50%  \
# act17_p_rate             51.0    65.254902  32.140842    8.0    31.00    69.0
# act17_english            51.0    20.931373   2.353677   16.3    19.00    20.7
# act17_math               51.0    21.182353   1.981989   18.0    19.40    20.9
# act17_reading            51.0    22.013725   2.067271   18.1    20.45    21.8
# act17_science            51.0    21.450980   1.739353   18.2    19.95    21.3
# act17_composite          51.0    21.519608   2.020695   17.8    19.80    21.4
# sat17_p_rate             51.0    39.803922  35.276632    2.0     4.00    38.0
# sat17_ebase_read_write   51.0   569.117647  45.666901  482.0   533.50   559.0
# sat17_math               51.0   556.882353  47.121395  468.0   523.50   548.0
# sat17_total              51.0  1126.098039  92.494812  950.0  1055.50  1107.0
# act18_p_rate             51.0    61.647059  34.080976    7.0    28.50    66.0
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#function to calculate and return standard deviation
def std_dev(data):
    mu = float(sum(data) / len(data))
    varience = [(x - mu)**2 for x in data]
    sd = np.sqrt(sum(varience)/len(data))
    return sd

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Take in the data series and return the standard deviation with the function std_dev, if condition to prevent taking the data series containing 'object'
sd = {key:std_dev(value) for (key,value) in combined_df.items() if key!='state'}

# %%
#check data series
sd
# Out:
# {'act17_p_rate': 31.824175751231806,
#  'act17_english': 2.3304876369363363,
#  'act17_math': 1.9624620273436781,
#  'act17_reading': 2.0469029314842646,
#  'act17_science': 1.7222161451443676,
#  'act17_composite': 2.000786081581989,
#  'sat17_p_rate': 34.92907076664508,
#  'sat17_ebase_read_write': 45.21697020437866,
#  'sat17_math': 46.65713364485503,
#  'sat17_total': 91.58351056778743,
#  'act18_p_rate': 33.745194881997506,
#  'act18_composite': 2.0855261815801147,
#  'act18_english': 2.4222536143202795,
#  'act18_math': 2.015707255555717,
#  'act18_reading': 2.145891884510421,
#  'act18_science': 1.8516885484833543,
#  'sat18_p_rate': 36.946619223539415,
#  'sat18_ebase_read_write': 47.03460978357609,
#  'sat18_math': 47.30194550378352,
#  'sat18_total': 93.22742384464433}

# %%
#Take in the data series and return the standard deviation with the numpy std method, if condition to prevent taking the data series containing 'object'
np_sd = {key:np.std(value) for (key,value) in combined_df.items() if key!='state'}

# %%
#check the data
np_sd
# Out:
# {'act17_p_rate': 31.824175751231806,
#  'act17_english': 2.3304876369363363,
#  'act17_math': 1.9624620273436781,
#  'act17_reading': 2.0469029314842646,
#  'act17_science': 1.7222161451443676,
#  'act17_composite': 2.000786081581989,
#  'sat17_p_rate': 34.92907076664508,
#  'sat17_ebase_read_write': 45.21697020437866,
#  'sat17_math': 46.65713364485503,
#  'sat17_total': 91.58351056778743,
#  'act18_p_rate': 33.745194881997506,
#  'act18_composite': 2.0855261815801147,
#  'act18_english': 2.4222536143202795,
#  'act18_math': 2.015707255555717,
#  'act18_reading': 2.145891884510421,
#  'act18_science': 1.8516885484833543,
#  'sat18_p_rate': 36.946619223539415,
#  'sat18_ebase_read_write': 47.03460978357609,
#  'sat18_math': 47.30194550378352,
#  'sat18_total': 93.22742384464433}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer:<br>
# The manually calculated standard deviation values do not match the "describe" output values. <br>
# The manually calculated standard deviation values match with numpy's "std" method output values.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Slice the selected dataframes
state_p_rate = combined_df.groupby('state')[['act17_p_rate', 'act18_p_rate', 'sat17_p_rate', 'sat18_p_rate']]
#sort data series in descending order
state_p_rate.mean().sort_values('act17_p_rate', ascending=False).head(20)
# Out:
#                 act17_p_rate  act18_p_rate  sat17_p_rate  sat18_p_rate
# state
# Alabama                100.0         100.0           5.0           6.0
# Kentucky               100.0         100.0           4.0           4.0
# Wisconsin              100.0         100.0           3.0           3.0
# Utah                   100.0         100.0           3.0           4.0
# Tennessee              100.0         100.0           5.0           6.0
# South Carolina         100.0         100.0          50.0          55.0
# Oklahoma               100.0         100.0           7.0           8.0
# North Carolina         100.0         100.0          49.0          52.0
# Nevada                 100.0         100.0          26.0          23.0
# Montana                100.0         100.0          10.0          10.0
# Mississippi            100.0         100.0           2.0           3.0
# Minnesota              100.0          99.0           3.0           4.0
# ...

# %%
#sort data series in ascending order
state_p_rate.mean().sort_values('act17_p_rate', ascending=True).head(10)
# Out:
#                act17_p_rate  act18_p_rate  sat17_p_rate  sat18_p_rate
# state
# Maine                   8.0           7.0          95.0          99.0
# New Hampshire          18.0          16.0          96.0          96.0
# Delaware               18.0          17.0         100.0         100.0
# Rhode Island           21.0          15.0          71.0          97.0
# Pennsylvania           23.0          20.0          65.0          70.0
# Maryland               28.0          31.0          69.0          76.0
# Vermont                29.0          24.0          60.0          64.0
# Massachusetts          29.0          25.0          76.0          80.0
# Michigan               29.0          22.0         100.0         100.0
# Virginia               29.0          24.0          65.0          68.0

# %% [markdown]
# Ans:<br>
# For 2017 ACT, highest participating states (assume 100% participation rate):<br>
# Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, North Carolina, Nevada, Montana, Mississippi, Minnesota, Lousiana, Missouri, Wyoming, Colorado, Arkansas (17 states)<br>
# For 2017 ACT, lowest participating states (assume <25% participation rate):<br>
# Maine, New Hampshire, Delaware, Rhode Island, Pennsylvania (5 states)

# %%
#sort data series in descending order
state_p_rate.mean().sort_values('act18_p_rate', ascending=False).head(20)
# Out:
#                 act17_p_rate  act18_p_rate  sat17_p_rate  sat18_p_rate
# state
# Alabama                100.0         100.0           5.0           6.0
# Kentucky               100.0         100.0           4.0           4.0
# Wisconsin              100.0         100.0           3.0           3.0
# Utah                   100.0         100.0           3.0           4.0
# Tennessee              100.0         100.0           5.0           6.0
# South Carolina         100.0         100.0          50.0          55.0
# Oklahoma               100.0         100.0           7.0           8.0
# Ohio                    75.0         100.0          12.0          18.0
# North Carolina         100.0         100.0          49.0          52.0
# Nevada                 100.0         100.0          26.0          23.0
# Nebraska                84.0         100.0           3.0           3.0
# Montana                100.0         100.0          10.0          10.0
# ...

# %%
#sort data series in ascending order
state_p_rate.mean().sort_values('act18_p_rate', ascending=True).head(10)
# Out:
#                act17_p_rate  act18_p_rate  sat17_p_rate  sat18_p_rate
# state
# Maine                   8.0           7.0          95.0          99.0
# Rhode Island           21.0          15.0          71.0          97.0
# New Hampshire          18.0          16.0          96.0          96.0
# Delaware               18.0          17.0         100.0         100.0
# Pennsylvania           23.0          20.0          65.0          70.0
# Michigan               29.0          22.0         100.0         100.0
# Washington             29.0          24.0          64.0          69.0
# Vermont                29.0          24.0          60.0          64.0
# Virginia               29.0          24.0          65.0          68.0
# Massachusetts          29.0          25.0          76.0          80.0

# %% [markdown]
# Ans:<br>
# For 2018 ACT, highest participating states (assume 100% participation rate):<br>
# Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, Ohio, North Carolina, Nevada, Nebraska, Montana, Mississippi, Lousiana, Missouri, Wyoming, Arkansas (17 states)<br>
# For 2018 ACT, lowest participating states (assume <25% participation rate):<br>
# Maine, Rhode Island, New Hampshire, Delaware, Pennsylvania, Michigan, Washington, Vermont, Virginia (9 states)

# %% [markdown]
# Ans:<br>
# Rate of change 2017-to-2018 for 100% participation states:<br>
# Minnesota and Colarado

# %%
#sort data series in descending order
state_p_rate.mean().sort_values('sat17_p_rate', ascending=False).head()
# Out:
#                       act17_p_rate  act18_p_rate  sat17_p_rate  sat18_p_rate
# state
# District of Columbia          32.0          32.0         100.0          92.0
# Michigan                      29.0          22.0         100.0         100.0
# Connecticut                   31.0          26.0         100.0         100.0
# Delaware                      18.0          17.0         100.0         100.0
# New Hampshire                 18.0          16.0          96.0          96.0

# %%
#sort data series in ascending order
state_p_rate.mean().sort_values('sat17_p_rate', ascending=True).head(20)
# Out:
#               act17_p_rate  act18_p_rate  sat17_p_rate  sat18_p_rate
# state
# North Dakota          98.0          98.0           2.0           2.0
# Mississippi          100.0         100.0           2.0           3.0
# Iowa                  67.0          68.0           2.0           3.0
# Missouri             100.0         100.0           3.0           4.0
# Utah                 100.0         100.0           3.0           4.0
# South Dakota          80.0          77.0           3.0           3.0
# Nebraska              84.0         100.0           3.0           3.0
# Wisconsin            100.0         100.0           3.0           3.0
# Minnesota            100.0          99.0           3.0           4.0
# Wyoming              100.0         100.0           3.0           3.0
# Arkansas             100.0         100.0           3.0           5.0
# Kansas                73.0          71.0           4.0           4.0
# ...

# %% [markdown]
# Ans:<br>
# For 2017 SAT, highest participating states (assume 100% participation rate):<br>
# District of Columbia, Michigan, Connecticut, Delaware (4 states)<br>
# For 2018 ACT, lowest participating states (assume <5% participation rate):<br>
# North Dakota, Mississipi, Iowa, Missouri, Utah, South Dakota, Nebraska, Wisconsin, Minnesota, Wyoming, Arkansas, Kansas, Kentucky, Louisiana (14 states)

# %%
#sort data series in descending order
state_p_rate.mean().sort_values('sat18_p_rate', ascending=False).head(10)
# Out:
#                       act17_p_rate  act18_p_rate  sat17_p_rate  sat18_p_rate
# state
# Colorado                     100.0          30.0          11.0         100.0
# Connecticut                   31.0          26.0         100.0         100.0
# Delaware                      18.0          17.0         100.0         100.0
# Michigan                      29.0          22.0         100.0         100.0
# Idaho                         38.0          36.0          93.0         100.0
# Maine                          8.0           7.0          95.0          99.0
# Illinois                      93.0          43.0           9.0          99.0
# Rhode Island                  21.0          15.0          71.0          97.0
# New Hampshire                 18.0          16.0          96.0          96.0
# District of Columbia          32.0          32.0         100.0          92.0

# %%
#sort data series in ascending order
state_p_rate.mean().sort_values('sat18_p_rate', ascending=True).head(15)
# Out:
#               act17_p_rate  act18_p_rate  sat17_p_rate  sat18_p_rate
# state
# North Dakota          98.0          98.0           2.0           2.0
# Wyoming              100.0         100.0           3.0           3.0
# South Dakota          80.0          77.0           3.0           3.0
# Nebraska              84.0         100.0           3.0           3.0
# Wisconsin            100.0         100.0           3.0           3.0
# Mississippi          100.0         100.0           2.0           3.0
# Iowa                  67.0          68.0           2.0           3.0
# Utah                 100.0         100.0           3.0           4.0
# Minnesota            100.0          99.0           3.0           4.0
# Louisiana            100.0         100.0           4.0           4.0
# Kentucky             100.0         100.0           4.0           4.0
# Kansas                73.0          71.0           4.0           4.0
# ...

# %% [markdown]
# Ans:<br>
# For 2018 SAT, highest participating states (assume 100% participation rate):<br>
# Colorado, Connecticut, Delaware, Michigan, Idaho (5 states)<br>
# For 2018 SAT, lowest participating states (assume <5% participation rate):<br>
# North Dakota, Wyoming, South Dakota, Nebraska, Wisconsin, Mississippi, Iowa, Utah, Minnesota, Louisiana, Kentucky, Kansas, Missouri (13 states)

# %%
#Slice the dataframe
state_composite = combined_df.groupby('state')[['act17_composite', 'act18_composite', 'sat17_total', 'sat18_total']]

# %%
#sort data series in descending order
state_composite.mean().sort_values('act17_composite', ascending=False).head(10)
# Out:
#                       act17_composite  act18_composite  sat17_total  \
# state
# New Hampshire                    25.5             25.1         1052
# Massachusetts                    25.4             25.5         1107
# Connecticut                      25.2             25.6         1041
# Maine                            24.3             24.0         1012
# District of Columbia             24.2             23.6          950
# New York                         24.2             24.5         1052
# Michigan                         24.1             24.4         1005
# Delaware                         24.1             23.2          996
# Rhode Island                     24.0             24.2         1062
# New Jersey                       23.9             23.7         1056
#
#                       sat18_total
# state
# New Hampshire                1063
# Massachusetts                1125
# Connecticut                  1053
# Maine                        1013
# ...

# %%
#sort data series in ascending order
state_composite.mean().sort_values('act17_composite', ascending=True).head(10)
# Out:
#                 act17_composite  act18_composite  sat17_total  sat18_total
# state
# Nevada                     17.8             17.7         1116         1140
# Mississippi                18.6             18.6         1242         1236
# South Carolina             18.7             18.3         1064         1070
# Hawaii                     19.0             18.9         1085         1010
# North Carolina             19.1             19.1         1081         1098
# Alabama                    19.2             19.1         1165         1166
# Arkansas                   19.4             19.4         1208         1169
# Oklahoma                   19.4             19.3         1047         1062
# Louisiana                  19.5             19.2         1198         1210
# Arizona                    19.7             19.2         1116         1149

# %% [markdown]
# Ans:<br>
# For 2017 ACT, highest composite score states (assume >24):<br>
# New Hampshire, Massachusetts, Connecticut, Maine, District of Columbia, New York, Michigan, Delaware (8 states)<br>
# For 2017 ACT, lowest composite score states (assume <19):<br>
# Nevada, Mississippi, South Carolina,  (3 states)

# %%
#sort data series in descending order
state_composite.mean().sort_values('act18_composite', ascending=False).head(10)
# Out:
#                act17_composite  act18_composite  sat17_total  sat18_total
# state
# Connecticut               25.2             25.6         1041         1053
# Massachusetts             25.4             25.5         1107         1125
# New Hampshire             25.5             25.1         1052         1063
# New York                  24.2             24.5         1052         1068
# Michigan                  24.1             24.4         1005         1011
# Rhode Island              24.0             24.2         1062         1018
# Vermont                   23.6             24.1         1114         1120
# Maine                     24.3             24.0         1012         1013
# Virginia                  23.8             23.9         1102         1117
# Colorado                  20.8             23.9         1201         1025

# %%
#sort data series in ascending order
state_composite.mean().sort_values('act18_composite', ascending=True).head(10)
# Out:
#                 act17_composite  act18_composite  sat17_total  sat18_total
# state
# Nevada                     17.8             17.7         1116         1140
# South Carolina             18.7             18.3         1064         1070
# Mississippi                18.6             18.6         1242         1236
# Hawaii                     19.0             18.9         1085         1010
# Alabama                    19.2             19.1         1165         1166
# North Carolina             19.1             19.1         1081         1098
# Arizona                    19.7             19.2         1116         1149
# Louisiana                  19.5             19.2         1198         1210
# Oklahoma                   19.4             19.3         1047         1062
# Arkansas                   19.4             19.4         1208         1169

# %% [markdown]
# Ans:<br>
# For 2018 ACT, highest composite score states (assume >24):<br>
# Connecticut, Massachusetts, New Hampshire, New York, Michigan, Rhode Island, Vermont (7 states)<br>
# For 2018 ACT, lowest composite score states (assume <19):<br>
# Nevada, South Carolina, Mississippi, Hawaii (4 states)

# %%
#sort data series in descending order
state_composite.mean().sort_values('sat17_total', ascending=False).head(10)
# Out:
#               act17_composite  act18_composite  sat17_total  sat18_total
# state
# Minnesota                21.5             21.3         1295         1298
# Wisconsin                20.5             20.5         1291         1294
# Iowa                     21.9             21.8         1275         1265
# Missouri                 20.4             20.0         1271         1262
# Kansas                   21.7             21.6         1260         1265
# North Dakota             20.3             20.3         1256         1283
# Nebraska                 21.4             20.1         1253         1252
# Kentucky                 20.0             20.2         1247         1248
# Mississippi              18.6             18.6         1242         1236
# Utah                     20.3             20.4         1238         1010

# %%
#sort data series in ascending order
state_composite.mean().sort_values('sat17_total', ascending=True).head(10)
# Out:
#                       act17_composite  act18_composite  sat17_total  \
# state
# District of Columbia             24.2             23.6          950
# Delaware                         24.1             23.2          996
# Idaho                            22.3             22.3         1005
# Michigan                         24.1             24.4         1005
# Maine                            24.3             24.0         1012
# Florida                          19.8             19.9         1017
# Texas                            20.7             20.6         1020
# Connecticut                      25.2             25.6         1041
# Oklahoma                         19.4             19.3         1047
# Georgia                          21.4             21.4         1050
#
#                       sat18_total
# state
# District of Columbia          977
# Delaware                      998
# Idaho                        1001
# Michigan                     1011
# ...

# %% [markdown]
# Ans:<br>
# For 2017 SAT, highest total score states (assume >1250):<br>
# Minnesota, Wisconsin, Iowa, Missouri, Kansas, North Dakota, Nebraska (7 states)<br>
# For 2017 SAT, lowest total score states (assume <1050):<br>
# District of Columbia, Delaware, Idaho, MIchigan, Maine, Florida, Texas, Connecticut, Oklahoma (9 states)

# %%
#sort data series in descending order
state_composite.mean().sort_values('sat18_total', ascending=False).head(10)
# Out:
#               act17_composite  act18_composite  sat17_total  sat18_total
# state
# Minnesota                21.5             21.3         1295         1298
# Wisconsin                20.5             20.5         1291         1294
# North Dakota             20.3             20.3         1256         1283
# Iowa                     21.9             21.8         1275         1265
# Kansas                   21.7             21.6         1260         1265
# Missouri                 20.4             20.0         1271         1262
# Wyoming                  20.2             20.0         1230         1257
# Nebraska                 21.4             20.1         1253         1252
# Kentucky                 20.0             20.2         1247         1248
# South Dakota             21.8             21.9         1216         1240

# %%
#sort data series in ascending order
state_composite.mean().sort_values('sat18_total', ascending=True).head(15)
# Out:
#                       act17_composite  act18_composite  sat17_total  \
# state
# District of Columbia             24.2             23.6          950
# Delaware                         24.1             23.2          996
# West Virginia                    20.4             20.3         1086
# Idaho                            22.3             22.3         1005
# Utah                             20.3             20.4         1238
# Hawaii                           19.0             18.9         1085
# Michigan                         24.1             24.4         1005
# Maine                            24.3             24.0         1012
# Rhode Island                     24.0             24.2         1062
# Illinois                         21.4             23.9         1115
# Colorado                         20.8             23.9         1201
# Texas                            20.7             20.6         1020
# Connecticut                      25.2             25.6         1041
# ...

# %% [markdown]
# Ans:<br>
# For 2018 SAT, highest total score states (assume >1250):<br>
# Minnesota, Wisconsin, North Dakota, Iowa, Kansas, Missouri, Wyoming, Nebraska (8 states)<br>
# For 2018 SAT, lowest total score states (assume <1050):<br>
# District of Columbia, Delaware, West Virginia, Idaho, Utah, Hawaii, Michigan, Maine, Rhode Island, Illinois, Colorado, Texas (12 states)

# %%
#Filter dataframe with conditions
combined_df.loc[(combined_df['act17_p_rate']==100) & (combined_df['act18_p_rate']!=100), ['state', 'act17_p_rate', 'act18_p_rate']]
# Out:
#         state  act17_p_rate  act18_p_rate
# 5    Colorado         100.0          30.0
# 23  Minnesota         100.0          99.0

# %%
#Filter dataframe with conditions
combined_df.loc[(combined_df['sat17_p_rate']==100) & (combined_df['sat18_p_rate']!=100), ['state', 'sat17_p_rate', 'sat18_p_rate']]
# Out:
#                   state  sat17_p_rate  sat18_p_rate
# 8  District of Columbia         100.0          92.0

# %% [markdown]
# Do any states with 100% participation on a given test have a rate change year-to-year?<br>
# <br>
# Ans:<br>
# For ACT: Colorado and Minnesota<br>
# For SAT: District of Columbia

# %%
#Filter dataframe with conditions
combined_df.loc[((combined_df['act17_p_rate']>50) & (combined_df['sat17_p_rate']>50)) | ((combined_df['act18_p_rate']>50) & (combined_df['sat18_p_rate']>50)), ['state', 'act17_p_rate', 'sat17_p_rate', 'act18_p_rate', 'sat18_p_rate']]
# Out:
#              state  act17_p_rate  sat17_p_rate  act18_p_rate  sat18_p_rate
# 9          Florida          73.0          83.0          66.0          56.0
# 10         Georgia          55.0          61.0          53.0          70.0
# 11          Hawaii          90.0          55.0          89.0          56.0
# 33  North Carolina         100.0          49.0         100.0          52.0
# 40  South Carolina         100.0          50.0         100.0          55.0

# %% [markdown]
# Do any states show have >50% participation on both tests either year?<br>
# <br>
# Ans:<br>
# The states of Florida, Georgia, Hawaii, North Carolina and South Carolina

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
#Plot the heatmap
fig, ax = plt.subplots(figsize=(18,12))
act_sat_correlations = combined_df.corr();
sns.heatmap(act_sat_correlations, annot=True);
ax.set_title('ACT_YR/17/18 and SAT_YR/17/18 correlations heatmap', fontsize=25, y=5.01);

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
#function for plotting histogram
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(15,10)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings                                                         
        ax[i].set_title(list_of_titles[i], fontsize=15, y=1.01); # Set titles, labels, etc here for each subplot
        ax[i].set_xlabel(list_of_xlabels[i])
        
    plt.subplots_adjust(left=None, bottom=1, right=None, top=4, wspace=None, hspace=None)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
#Assigning values for arguents to be used in histogram function
columns = ['act17_p_rate', 'sat17_p_rate', 'act18_p_rate', 'sat18_p_rate', 'act17_math', 'sat17_math', 'act18_math', 'sat18_math', 'act17_reading', 'sat17_ebase_read_write', 'act18_reading', 'sat18_ebase_read_write']
titles = ['Participation rates for YR/17 ACT', 'Participation rates for YR/17 SAT', 'Participation rates for YR/18 ACT', 'Participation rates for YR/18 SAT', 'ACT Math score for YR/17', 'SAT Math score for YR/17', 'ACT Math score for YR/18', 'SAT Math score for YR/18', 'ACT reading/verbals scores for YR/17', 'SAT reading/verbals scores for YR/17', 'ACT reading/verbals scores for YR/18', 'SAT reading/verbals scores for YR/18']
xlabels = ['participation rates', 'participation rates', 'participation rates', 'participation rates', 'math scores', 'math scores', 'math scores', 'math scores', 'reading/verbals scores', 'reading/verbals scores', 'reading/verbals scores', 'reading/verbals scores']

# %%
#plotting histograms
subplot_histograms(combined_df, columns, titles, xlabels)

# %% [markdown]
# Ans:<br>
# **Partcipation rates for ACT YR17 & 18:**<br>
# There are more states with 100% participation rate as compared to states with less than 30% low participation rates.<br>
# **Partcipation rates for SAT YR17 & 18:**<br>
# There are more states with less than 20% participation rate as compared to states with 100% participation rates.<br>
# **Math score for ACT YR17 vs 18:**<br>
# Math scores have improved with most states going up from 19 to the 20 range.<br>
# **Math score for SAT YR17 vs 18:**<br>
# Math scores have remain similar.<br>
# **Reading/verbal score for ACT YR17 vs 18:**<br>
# Reading/verbal score have have remain similar.<br>
# **Reading/verbal score for SAT YR17 vs 18:**<br>
# Reading/verbal score have have remain similar.<br>

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
#plotting scatterplot
combined_df.plot(x='sat17_math', y='act17_math', kind='scatter', 
           color='dodgerblue', figsize=(8,8), s=20)\
            .set_title('SAT vs ACT math scores YR/17', fontsize=21, y=1.01);
plt.xlim(200, 800)
plt.ylim(1, 36);

# %% [markdown]
# Ans: There is an non-linear moderate negative correlation between the math scores of SAT & ACT for the year 2017.

# %%
#plotting scatterplot
combined_df.plot(x='sat17_ebase_read_write', y='act17_reading', kind='scatter', 
           color='green', figsize=(8,8), s=20)\
            .set_title('SAT vs ACT verbal/reading scores YR/17', fontsize=21, y=1.01);
plt.xlim(200, 800)
plt.ylim(1, 36);

# %% [markdown]
# Ans: There is an non-linear moderate negative correlation between the verbal/reading scores of SAT & ACT for the year 2017.

# %%
#plotting scatterplot
combined_df.plot(x='sat17_total', y='act17_composite', kind='scatter', 
           color='maroon', figsize=(8,8), s=20)\
            .set_title('SAT vs ACT total/composite scores YR/17', fontsize=21, y=1.01);
plt.xlim(400, 1600)
plt.ylim(1, 36);

# %% [markdown]
# Ans: There is an non-linear moderate negative correlation between the total and composite scores of SAT & ACT respectively for the year 2017.

# %%
#plotting scatterplot
combined_df.plot(x='sat17_total', y='sat18_total', kind='scatter', 
           color='purple', figsize=(8,8), s=20)\
            .set_title('SAT YR/17 vs SAT YR/18 total scores', fontsize=21, y=1.01);
plt.xlim(400, 1600)
plt.ylim(400, 1600);

# %% [markdown]
# Ans: There is a linear and strong positive correlation between the total scores of SAT 2017 & SAT 2018 as well as having some outliers.

# %%
#plotting scatterplot
combined_df.plot(x='act17_composite', y='act18_composite', kind='scatter', 
           color='red', figsize=(8,8), s=20)\
            .set_title('ACT YR/17 vs ACT YR/18 total scores', fontsize=21, y=1.01);
plt.xlim(1, 36)
plt.ylim(1, 36);

# %% [markdown]
# Ans: There is a linear and strong positive correlation between the total scores of ACT 2017 & ACT 2018 as well as having a few outliers.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
#plotting boxplot
combined_df[['act17_p_rate', 'act18_p_rate', 'sat17_p_rate', 'sat18_p_rate']].boxplot(figsize=(10,5))\
.set_title('ACT & SAT participation rates for YR/17/18', fontsize=21, y=1.01);

# %% [markdown]
# ACT YR17/18 have participation rates that reach up most limit of 100% <br>
# SAT YR17/18 have participation rates are close to the bottom limit of 0%<br>
# ACT YR17/18 mean participation rates remain the same<br>
# SAT YR18 mean participation rates improved at slightly above 50% compared to SAT YR17 mean participation rates which is slightly below 40%

# %%
#plotting boxplot
combined_df[['sat17_total', 'sat18_total']].boxplot(figsize=(7,5))\
.set_title('SAT total score for YR/17/18', fontsize=21, y=1.01);

# %% [markdown]
# SAT YR18 total score had a slight increased in the lower limits as compared to SAT YR17

# %%
#plotting boxplot
combined_df[['sat17_ebase_read_write', 'sat17_math', 'sat18_ebase_read_write', 'sat18_math']].boxplot(figsize=(10,5))\
.set_title('SAT read/write and math score for YR/17/18', fontsize=21, y=1.01);

# %% [markdown]
# The SAT YR17 and YR18 scores for both reading/writing and math remains similar

# %%
#plotting boxplot
combined_df[['act17_english', 'act17_math', 'act17_reading', 'act17_science', 'act18_english', 'act18_math', 'act18_reading', 'act18_science', 'act17_composite', 'act18_composite']].boxplot(figsize=(20,5))\
.set_title('ACT english, math, reading, science & composite score for YR/17/18', fontsize=21, y=1.01);

# %% [markdown]
# ACT YR18 subjects and composite scores remain similar to the ACT YR17 scores

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
#check values
combined_df.describe()
# Out:
#        act17_p_rate  act17_english  act17_math  act17_reading  act17_science  \
# count     51.000000      51.000000   51.000000      51.000000      51.000000
# mean      65.254902      20.931373   21.182353      22.013725      21.450980
# std       32.140842       2.353677    1.981989       2.067271       1.739353
# min        8.000000      16.300000   18.000000      18.100000      18.200000
# 25%       31.000000      19.000000   19.400000      20.450000      19.950000
# 50%       69.000000      20.700000   20.900000      21.800000      21.300000
# 75%      100.000000      23.300000   23.100000      24.150000      23.200000
# max      100.000000      25.500000   25.300000      26.000000      24.900000
#
#        act17_composite  sat17_p_rate  sat17_ebase_read_write  sat17_math  \
# count        51.000000     51.000000               51.000000   51.000000
# mean         21.519608     39.803922              569.117647  556.882353
# ...

# %% [markdown]
# |Variable|Mean|Spread|skewness|
# |---|---|---|---|
# |act17_p_rate|20.9|The spread is big as seen in the standard deviation|The distribution is skewed to the right|

# %% [markdown]
# #### Distributions in the data
#
# In this dataset, each data represents a sample from a population.
# For example, for ACT math test:
# - Population: the test results of all the students who take this test, nation-wide.
# - Population mean: is the national average of ACT math test (total scores/total no. of test takers)
# - Sample: the state means of ACT math test. We have 51 samples (51 states)
#
# ***According to CLT, we generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?***

# %%
#Getting sample population, size and no. of experiments
sample_popn_act17math = combined_df['act17_math'].values.tolist()
sample_size = 51
Num_experiment = 1000 #assume repeat experiment for 1000 times

# %%
#function to generate sample means
def sampler(population, n, k): #function to obtain the sample means
    sample_means = []
    for i in range(k):
        sample = np.random.choice(population, size=n, replace=True)
        sample_means.append(np.mean(sample))
    return sample_means

# %%
#function to plot a histogram
def dist_plotter(sample): 
    fig, ax = plt.subplots(figsize=(8,6))
    ax = sns.distplot(sample, bins=50, kde=False)

# %%
#Generating sample means
act17math_sample_mean = sampler(sample_popn_act17math, sample_size, Num_experiment)

# %%
#plotting sample means
dist_plotter(act17math_sample_mean)

# %% [markdown]
# Answer: Yes, we can observe a normal distribution after plotting the sample means

# %%
#Generating sample means
sample_popn_act17read = combined_df['act17_reading'].values.tolist()
sample_popn_act17p_rates = combined_df['act17_p_rate'].values.tolist()

# %%
#Generating sample means
act17read_sample_mean = sampler(sample_popn_act17read, sample_size, Num_experiment)

# %%
#plotting sample means
dist_plotter(act17read_sample_mean)

# %%
#Generating sample means
act17p_rates_sample_mean = sampler(sample_popn_act17p_rates, sample_size, Num_experiment)

# %%
#plotting sample means
dist_plotter(act17p_rates_sample_mean)

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:<br>
# The assumption hold true for Math, Reading and Participation rates. <br>
# These distribution follows a normal distribution, hence estimates made from these data can be derived from the normal distribution.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:<br>
# Base on the heatmap, SAT and ACT participation rates for 2017 has a negative correlation of -0.84. Hence, it is advisable to study this rates to find out why students prefer to take ACT instead of SAT.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores  - can we say students with higher SAT math score is better than those with lower ACT math score, or vice versa?
#
# Why or why not?

# %% [markdown]
# Answer: <br>
# No, we cannot based on the below reasons. <br>
# **1. Different formats for ACT and SAT:** <br>
# ACT does not provide any formulas, test a wider variety of math topics than SAT, has a larger emphasis on geometry. SAT has more emphasis on data analysis and word problems<br>
# **2. Time factor:**<br>
# ACT gives an average of 60 seconds per question.<br>
# SAT gives an average of 75-87 seconds per question.<br>
# **3. Use of calculator**:<br>
# ACT has only 1 section which allows the full use of a calculator.<br>
# SAT has 2 sections - 1 with calculator and 1 without calculator
#
# source: https://blog.prepscholar.com/sat-math-vs-act-math-whats-the-difference

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# I have chosen the below 3 states:<br>
#
# **Colarado**: 100% ACT participation rate in 2017, then a 100% SAT participation rate in 2018.<br>
#
# **South Carolina**: 100% ACT participation rate in 2017 and 2018, but a 50% SAT participation rate in 2017 and a 55% SAT participation rate in 2018<br>
#
# **Wisconsin**: 100% ACT participation rate in 2017 and 2018, but has high SAT scores for 2017 and 2018

# %% [markdown]
# I will first check the state policies to see which states have mandated to take ACT.<br>
#
# The states are: Alabama, Hawaii, Montana, Nebraska, Nevada, North Carolina, North Dakota, Utah, Wisconsin, Kentucky, Louisiana, Mississippi, Wyoming<br>
#
# source: https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice

# %% [markdown]
# Colarado had a change in state policy which adopted the SAT and dropping away the ACT. This explains the change of the participation rate.<br>
#
# source: https://chalkbeat.org/posts/co/2015/12/23/goodbye-act-hello-sat-a-significant-change-for-colorado-high-schoolers/

# %% [markdown]
# South Carolina had a increased in students taking SAT due to SAT school day, in which the state covers the SAT costs and the tests are conducted on a school day. This explains in the increase of participation rates in SAT<br>
#
# source: https://columbiabusinessreport.com/news/education/77163/

# %% [markdown]
# Wisconsin has a state policy which require all students to take the ACT. However, interestingly they have low SAT participation rates but high SAT scores. This may be due to the top student percentile taking the SAT and getting high scores in it. Furthermore, the University of Wisconsin is competitive in terms of securing placement and requires student to have at least a SAT score of 1300 to have a chance of being considered. This might be a possible factor for the high SAT scores.<br>
#
# source: https://www.prepscholar.com/sat/s/colleges/University-of-Wisconsin---Madison-SAT-scores-GPA

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Key takeaways: <br>
# 1. ACT and SAT participation rates have a negative co-relation. This maybe due to some states adopting mandatory ACT and others mandatory SAT for all the students.
# 2. The participation rates and the corresponding total test scores have a negative correlation. This is due to the increase of students taking the test, therefore bringing down the overall test scores for the state, assuming that most students perform average or bad.
#
# Recommendations:<br>
# 1. Encourage the College Board to ramp up engagement with the state's education authorities to consider making SAT mandatory for all students in the state
# 2. SAT school day helps to increase the participation rate for SAT. Increase collaboration with state education authorities to take up the program of SAT school day.

# %% [markdown]
# I would choose Florida with as it has more than 50% of students taking ACT and SAT. There is no mandatory state requirement for ACT or SAT and therefore, there is a better chance to increase the participation rate for SAT in that state.<br>
#
# I would like to obtain the data for the annual education budget for the states as my 2 recommendations would require funds from the state in order for it to get implemented. Knowing which state has an increased in budget would help my recommendations to succeed.
